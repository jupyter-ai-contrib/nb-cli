# %%
print("x" * 5000)
# Out:
# ...

# %%
import matplotlib.pyplot as plt
plt.plot([1,2,3])

# %%
int("abc")
# Out:
# Traceback (most recent call last):
#   File "<stdin>", line 1
# ValueError: invalid literal
