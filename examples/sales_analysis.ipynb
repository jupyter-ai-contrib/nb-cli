# %% [markdown]
# # Sales Data Analysis

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Set style
plt.style.use('ggplot')
plt.rcParams['figure.figsize'] = (10, 6)

# %%
# Load the data
df = pd.read_csv('data/sales_data.csv')
df['Date'] = pd.to_datetime(df['Date'])
df.head()
# Out:
#         Date Product_Category         Product_Name Region  Quantity  \
# 0 2026-01-05      Electronics        Laptop Pro 15  North        12
# 1 2026-01-05      Electronics       Wireless Mouse  North        45
# 2 2026-01-05        Furniture  Office Chair Deluxe  North         8
# 3 2026-01-05  Office Supplies    Printer Paper Box  North        30
# 4 2026-01-06      Electronics          USB-C Cable  South       120
#
#    Unit_Price  Total_Sales      Sales_Rep
# 0     1299.99     15599.88  Alice Johnson
# 1       29.99      1349.55  Alice Johnson
# 2      349.99      2799.92  Alice Johnson
# 3       24.99       749.70  Alice Johnson
# 4       15.99      1918.80      Bob Smith

# %%
# Calculate monthly totals
df['Month'] = df['Date'].dt.strftime('%Y-%m')
monthly_sales = df.groupby('Month')['Total_Sales'].sum().reset_index()
monthly_sales
# Out:
#      Month  Total_Sales
# 0  2026-01    112612.28
# 1  2026-02     91328.89
# 2  2026-03     60985.02

# %%
# Create a bar chart
plt.figure(figsize=(10, 6))
plt.bar(monthly_sales['Month'], monthly_sales['Total_Sales'], color='skyblue')
plt.title('Monthly Sales Totals')
plt.xlabel('Month')
plt.ylabel('Total Sales ($)')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
