# %%
print('Updated via CLI with Y.js\!')
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
print("hello world")\n# Added via CLI append!

# %%
print("Hola")
# This should be on a new line\!

# %%
2 + 2

# %%
1/0

# %%
print('local test')

# %%
print('remote test')

# %%
print('Testing with proper Y.js Maps\!')

# %%
print("Hello World 123")
